# %%
#中国各省面积  
def tmp():  
    area = {'新疆':166, '西藏':122.8, '内蒙古':118.3, '青海':72.23,'四川':48.14, '黑龙江':45.48, '甘肃':45.44, '云南':38.33, '广西':23.6, '湖南':21.18, '陕西':20.56, '河北':18.77, '吉林':18.74, '湖北':18.58, '广东':18, '贵州':17.6, '江西':16.7, '河南':16.7, '山西':15.63, '山东':15.38,'辽宁':14.59, '安徽':13.97, '福建':12.13, '江苏':10.26,'浙江':10.2, '重庆':8.23, '宁夏':6.64, '台湾':3.6, '海南':3.4,'北京':1.68, '天津':1.13, '上海':0.63, '香港':0.11, '澳门':0.0025};  
    listA = list(area.items());  
    listA = sorted(listA, key = lambda a : a[1], reverse=True);  
    for i in range(len(listA)):  
        print('第{0}位：{1}, 面积{2}万平方千米；'.format(i+1, listA[i][0], listA[i][1]));
        
tmp()
# Out:
# 第1位：新疆, 面积166万平方千米；
# 第2位：西藏, 面积122.8万平方千米；
# 第3位：内蒙古, 面积118.3万平方千米；
# 第4位：青海, 面积72.23万平方千米；
# 第5位：四川, 面积48.14万平方千米；
# 第6位：黑龙江, 面积45.48万平方千米；
# 第7位：甘肃, 面积45.44万平方千米；
# 第8位：云南, 面积38.33万平方千米；
# 第9位：广西, 面积23.6万平方千米；
# 第10位：湖南, 面积21.18万平方千米；
# 第11位：陕西, 面积20.56万平方千米；
# 第12位：河北, 面积18.77万平方千米；
# 第13位：吉林, 面积18.74万平方千米；
# 第14位：湖北, 面积18.58万平方千米；
# 第15位：广东, 面积18万平方千米；
# 第16位：贵州, 面积17.6万平方千米；
# 第17位：河南, 面积16.7万平方千米；
# 第18位：江西, 面积16.7万平方千米；
# 第19位：山西, 面积15.63万平方千米；
# 第20位：山东, 面积15.38万平方千米；
# 第21位：辽宁, 面积14.59万平方千米；
# 第22位：安徽, 面积13.97万平方千米；
# 第23位：福建, 面积12.13万平方千米；
# 第24位：江苏, 面积10.26万平方千米；
# 第25位：浙江, 面积10.2万平方千米；
# 第26位：重庆, 面积8.23万平方千米；
# 第27位：宁夏, 面积6.64万平方千米；
# 第28位：台湾, 面积3.6万平方千米；
# 第29位：海南, 面积3.4万平方千米；
# 第30位：北京, 面积1.68万平方千米；
# 第31位：天津, 面积1.13万平方千米；
# 第32位：上海, 面积0.63万平方千米；
# 第33位：香港, 面积0.11万平方千米；
# 第34位：澳门, 面积0.0025万平方千米；
